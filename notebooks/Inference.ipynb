# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from torch.utils.data import DataLoader
import torch.nn as nn
import torchsummary
import torch
import torch.optim as optim

from dgzc.dataset import DGZCAutoEncoderDataset, DGZCClassifierDataset, DGZCInferenceDataset
from dgzc.autoencoder import Encoder, Decoder, AutoEncoderFaceImages
from dgzc.classifier import ClassificationBackbone, AutoEncoderClassifierAmalgamation

# %%
data_path = "/home/shivam/2021-22-2/ML4CE/Assignments/Assignment3/Driver-Gaze-Zone-Classification/data/gaze_dataset"
# dataset_auto_enc = DGZCAutoEncoderDataset(data_path, size=(200, 200))
# dataset_classifier = DGZCClassifierDataset(data_path, size=(200, 200))
dataset_inference = DGZCInferenceDataset(data_path, size=(200, 200))

# %%
inv_class_map = {0 : 'Centerstack',
                 1 : 'Forward',
                 2 : 'Left_wing_mirror',
                 3 : 'Rearview_mirror',
                 4 : 'Right_wing_mirror',
                 -1 : 'other'}

# %%
dataloader = DataLoader(dataset_inference, batch_size = 10, shuffle = False, num_workers=5)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
data_len = len(dataloader)
log_n = int(data_len//3)

# %%
model = AutoEncoderClassifierAmalgamation()
model.to(device)
# Out:
# AutoEncoderClassifierAmalgamation(
#   (encoder): Encoder(
#     (conv1): Conv2DNormActivation(
#       (0): Conv2d(3, 5, kernel_size=(5, 5), stride=(2, 2))
#       (1): SELU()
#     )
#     (conv2): Conv2DNormActivation(
#       (0): Conv2d(5, 10, kernel_size=(5, 5), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SELU()
#     )
#     (max_pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv3): Conv2DNormActivation(
#       (0): Conv2d(10, 20, kernel_size=(3, 3), stride=(1, 1))
#       (1): SELU()
#     )
#     (conv4): Conv2DNormActivation(
#       (0): Conv2d(20, 20, kernel_size=(3, 3), stride=(1, 1))
#       (1): SELU()
#     )
#     (conv5): Conv2DNormActivation(
#       (0): Conv2d(20, 30, kernel_size=(3, 3), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SELU()
#     )
#     (conv6): Conv2DNormActivation(
#       (0): Conv2d(30, 40, kernel_size=(3, 3), stride=(1, 1))
#       (1): SELU()
#     )
#   )
#   (attention1): SelfAttention(
#     (query_conv): Conv2d(40, 5, kernel_size=(1, 1), stride=(1, 1))
#     (key_conv): Conv2d(40, 5, kernel_size=(1, 1), stride=(1, 1))
#     (value_conv): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#     (softmax): Softmax(dim=-1)
#   )
#   (conv1): Conv2DNormActivation(
#     (0): Conv2d(40, 50, kernel_size=(3, 3), stride=(1, 1))
#     (1): SELU()
#   )
#   (attention2): SelfAttention(
#     (query_conv): Conv2d(50, 6, kernel_size=(1, 1), stride=(1, 1))
#     (key_conv): Conv2d(50, 6, kernel_size=(1, 1), stride=(1, 1))
#     (value_conv): Conv2d(50, 50, kernel_size=(1, 1), stride=(1, 1))
#     (softmax): Softmax(dim=-1)
#   )
#   (conv2): Conv2DNormActivation(
#     (0): Conv2d(50, 40, kernel_size=(3, 3), stride=(1, 1))
#     (1): SELU()
#   )
#   (avg_pool2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv3): Conv2DNormActivation(
#     (0): Conv2d(40, 30, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): SELU()
#   )
#   (avg_pool3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv4): Conv2DNormActivation(
#     (0): Conv2d(30, 10, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): SELU()
#   )
#   (attention3): SelfAttention(
#     (query_conv): Conv2d(10, 1, kernel_size=(1, 1), stride=(1, 1))
#     (key_conv): Conv2d(10, 1, kernel_size=(1, 1), stride=(1, 1))
#     (value_conv): Conv2d(10, 10, kernel_size=(1, 1), stride=(1, 1))
#     (softmax): Softmax(dim=-1)
#   )
#   (decoder): Decoder(
#     (conv1): Conv2DNormActivation(
#       (0): ConvTranspose2d(40, 30, kernel_size=(3, 3), stride=(1, 1))
#       (1): SELU()
#     )
#     (conv2): Conv2DNormActivation(
#       (0): ConvTranspose2d(30, 30, kernel_size=(3, 3), stride=(2, 2))
#       (1): SELU()
#     )
#     (conv3): Conv2DNormActivation(
#       (0): Conv2d(30, 20, kernel_size=(3, 3), stride=(1, 1))
#       (1): SELU()
#     )
#     (conv4): Conv2DNormActivation(
#       (0): ConvTranspose2d(20, 10, kernel_size=(3, 3), stride=(2, 2))
#       (1): SELU()
#     )
#     (conv5): Conv2DNormActivation(
#       (0): ConvTranspose2d(10, 5, kernel_size=(3, 3), stride=(1, 1))
#       (1): SELU()
#     )
#     (conv6): Conv2DNormActivation(
#       (0): Conv2d(5, 3, kernel_size=(3, 3), stride=(1, 1))
#       (1): Sigmoid()
#     )
#   )
#   (linear1): Linear(in_features=250, out_features=128, bias=True)
#   (linear2): Linear(in_features=128, out_features=64, bias=True)
#   (linear3): Linear(in_features=64, out_features=32, bias=True)
#   (linear4): Linear(in_features=32, out_features=16, bias=True)
#   (linear5): Linear(in_features=16, out_features=8, bias=True)
#   (linear6): Linear(in_features=8, out_features=5, bias=True)
#   (activation): SELU()
#   (classifier): Softmax(dim=1)
# )

# %%
load_prev_auto_enc_state = False
load_prev_model_state = True
if load_prev_auto_enc_state:
    model.encoder.load_state_dict(torch.load('./encoder_state'))
    model.decoder.load_state_dict(torch.load('./decoder_state'))
elif load_prev_model_state:
    model.load_state_dict(torch.load('./amalgam_model'))

# %%
torchsummary.summary(model, (3, 200, 200))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 5, 98, 98]             380
#               SELU-2            [-1, 5, 98, 98]               0
#             Conv2d-3           [-1, 10, 94, 94]           1,250
#        BatchNorm2d-4           [-1, 10, 94, 94]              20
#               SELU-5           [-1, 10, 94, 94]               0
#          MaxPool2d-6           [-1, 10, 47, 47]               0
#             Conv2d-7           [-1, 20, 45, 45]           1,820
#               SELU-8           [-1, 20, 45, 45]               0
#             Conv2d-9           [-1, 20, 43, 43]           3,620
#              SELU-10           [-1, 20, 43, 43]               0
#            Conv2d-11           [-1, 30, 41, 41]           5,400
#       BatchNorm2d-12           [-1, 30, 41, 41]              60
#              SELU-13           [-1, 30, 41, 41]               0
#            Conv2d-14           [-1, 40, 39, 39]          10,840
#              SELU-15           [-1, 40, 39, 39]               0
#           Encoder-16           [-1, 40, 39, 39]               0
#            Conv2d-17            [-1, 5, 39, 39]             205
#            Conv2d-18            [-1, 5, 39, 39]             205
#           Softmax-19           [-1, 1521, 1521]               0
#            Conv2d-20           [-1, 40, 39, 39]           1,640
#     SelfAttention-21           [-1, 40, 39, 39]               0
#            Conv2d-22           [-1, 50, 37, 37]          18,050
#              SELU-23           [-1, 50, 37, 37]               0
#            Conv2d-24            [-1, 6, 37, 37]             306
#            Conv2d-25            [-1, 6, 37, 37]             306
#           Softmax-26           [-1, 1369, 1369]               0
#            Conv2d-27           [-1, 50, 37, 37]           2,550
#     SelfAttention-28           [-1, 50, 37, 37]               0
#            Conv2d-29           [-1, 40, 35, 35]          18,040
#              SELU-30           [-1, 40, 35, 35]               0
#         AvgPool2d-31           [-1, 40, 17, 17]               0
#            Conv2d-32           [-1, 30, 15, 15]          10,800
#       BatchNorm2d-33           [-1, 30, 15, 15]              60
#              SELU-34           [-1, 30, 15, 15]               0
#         AvgPool2d-35             [-1, 30, 7, 7]               0
#            Conv2d-36             [-1, 10, 5, 5]           2,700
#       BatchNorm2d-37             [-1, 10, 5, 5]              20
#              SELU-38             [-1, 10, 5, 5]               0
#            Conv2d-39              [-1, 1, 5, 5]              11
#            Conv2d-40              [-1, 1, 5, 5]              11
#           Softmax-41               [-1, 25, 25]               0
#            Conv2d-42             [-1, 10, 5, 5]             110
#     SelfAttention-43             [-1, 10, 5, 5]               0
#            Linear-44                  [-1, 128]          32,128
#              SELU-45                  [-1, 128]               0
#            Linear-46                   [-1, 64]           8,256
#              SELU-47                   [-1, 64]               0
#            Linear-48                   [-1, 32]           2,080
#              SELU-49                   [-1, 32]               0
#            Linear-50                   [-1, 16]             528
#              SELU-51                   [-1, 16]               0
#            Linear-52                    [-1, 8]             136
#              SELU-53                    [-1, 8]               0
#            Linear-54                    [-1, 5]              45
#           Softmax-55                    [-1, 5]               0
#   ConvTranspose2d-56           [-1, 30, 41, 41]          10,830
#              SELU-57           [-1, 30, 41, 41]               0
#   ConvTranspose2d-58           [-1, 30, 83, 83]           8,130
#              SELU-59           [-1, 30, 83, 83]               0
#            Conv2d-60           [-1, 20, 81, 81]           5,420
#              SELU-61           [-1, 20, 81, 81]               0
#   ConvTranspose2d-62         [-1, 10, 163, 163]           1,810
#              SELU-63         [-1, 10, 163, 163]               0
#   ConvTranspose2d-64          [-1, 5, 165, 165]             455
#              SELU-65          [-1, 5, 165, 165]               0
#            Conv2d-66          [-1, 3, 163, 163]             138
#           Sigmoid-67          [-1, 3, 163, 163]               0
#           Decoder-68          [-1, 3, 200, 200]               0
# ================================================================
# Total params: 148,360
# Trainable params: 148,360
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.46
# Forward/backward pass size (MB): 57.07
# Params size (MB): 0.57
# Estimated Total Size (MB): 58.09
# ----------------------------------------------------------------

# %%
model.eval()
# Out:
# AutoEncoderClassifierAmalgamation(
#   (encoder): Encoder(
#     (conv1): Conv2DNormActivation(
#       (0): Conv2d(3, 5, kernel_size=(5, 5), stride=(2, 2))
#       (1): SELU()
#     )
#     (conv2): Conv2DNormActivation(
#       (0): Conv2d(5, 10, kernel_size=(5, 5), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SELU()
#     )
#     (max_pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv3): Conv2DNormActivation(
#       (0): Conv2d(10, 20, kernel_size=(3, 3), stride=(1, 1))
#       (1): SELU()
#     )
#     (conv4): Conv2DNormActivation(
#       (0): Conv2d(20, 20, kernel_size=(3, 3), stride=(1, 1))
#       (1): SELU()
#     )
#     (conv5): Conv2DNormActivation(
#       (0): Conv2d(20, 30, kernel_size=(3, 3), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SELU()
#     )
#     (conv6): Conv2DNormActivation(
#       (0): Conv2d(30, 40, kernel_size=(3, 3), stride=(1, 1))
#       (1): SELU()
#     )
#   )
#   (attention1): SelfAttention(
#     (query_conv): Conv2d(40, 5, kernel_size=(1, 1), stride=(1, 1))
#     (key_conv): Conv2d(40, 5, kernel_size=(1, 1), stride=(1, 1))
#     (value_conv): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#     (softmax): Softmax(dim=-1)
#   )
#   (conv1): Conv2DNormActivation(
#     (0): Conv2d(40, 50, kernel_size=(3, 3), stride=(1, 1))
#     (1): SELU()
#   )
#   (attention2): SelfAttention(
#     (query_conv): Conv2d(50, 6, kernel_size=(1, 1), stride=(1, 1))
#     (key_conv): Conv2d(50, 6, kernel_size=(1, 1), stride=(1, 1))
#     (value_conv): Conv2d(50, 50, kernel_size=(1, 1), stride=(1, 1))
#     (softmax): Softmax(dim=-1)
#   )
#   (conv2): Conv2DNormActivation(
#     (0): Conv2d(50, 40, kernel_size=(3, 3), stride=(1, 1))
#     (1): SELU()
#   )
#   (avg_pool2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv3): Conv2DNormActivation(
#     (0): Conv2d(40, 30, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): SELU()
#   )
#   (avg_pool3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv4): Conv2DNormActivation(
#     (0): Conv2d(30, 10, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): SELU()
#   )
#   (attention3): SelfAttention(
#     (query_conv): Conv2d(10, 1, kernel_size=(1, 1), stride=(1, 1))
#     (key_conv): Conv2d(10, 1, kernel_size=(1, 1), stride=(1, 1))
#     (value_conv): Conv2d(10, 10, kernel_size=(1, 1), stride=(1, 1))
#     (softmax): Softmax(dim=-1)
#   )
#   (decoder): Decoder(
#     (conv1): Conv2DNormActivation(
#       (0): ConvTranspose2d(40, 30, kernel_size=(3, 3), stride=(1, 1))
#       (1): SELU()
#     )
#     (conv2): Conv2DNormActivation(
#       (0): ConvTranspose2d(30, 30, kernel_size=(3, 3), stride=(2, 2))
#       (1): SELU()
#     )
#     (conv3): Conv2DNormActivation(
#       (0): Conv2d(30, 20, kernel_size=(3, 3), stride=(1, 1))
#       (1): SELU()
#     )
#     (conv4): Conv2DNormActivation(
#       (0): ConvTranspose2d(20, 10, kernel_size=(3, 3), stride=(2, 2))
#       (1): SELU()
#     )
#     (conv5): Conv2DNormActivation(
#       (0): ConvTranspose2d(10, 5, kernel_size=(3, 3), stride=(1, 1))
#       (1): SELU()
#     )
#     (conv6): Conv2DNormActivation(
#       (0): Conv2d(5, 3, kernel_size=(3, 3), stride=(1, 1))
#       (1): Sigmoid()
#     )
#   )
#   (linear1): Linear(in_features=250, out_features=128, bias=True)
#   (linear2): Linear(in_features=128, out_features=64, bias=True)
#   (linear3): Linear(in_features=64, out_features=32, bias=True)
#   (linear4): Linear(in_features=32, out_features=16, bias=True)
#   (linear5): Linear(in_features=16, out_features=8, bias=True)
#   (linear6): Linear(in_features=8, out_features=5, bias=True)
#   (activation): SELU()
#   (classifier): Softmax(dim=1)
# )

# %%
labels = []

# %%
for i, (data, target) in enumerate(dataloader):
    data = data.to(device) # Move data to target device

    cls, recon = model(data)

    predictions = cls.max(dim=1)[1]
    labels += list(predictions.detach().cpu().numpy())

# %%
str_labels = [inv_class_map[x] for x in labels]

# %%
f_names = [x.split('/')[-1] for x in dataset_inference.images_path]

# %%
result_df = pd.DataFrame(np.array([f_names, str_labels]).T, columns=['filename', 'class'])

# %%
result_df.to_csv('./result3.csv', index=False)

# %%
str_labels
# Out:
# ['Forward',
#  'Forward',
#  'Right_wing_mirror',
#  'Right_wing_mirror',
#  'Forward',
#  'Left_wing_mirror',
#  'Rearview_mirror',
#  'Right_wing_mirror',
#  'Right_wing_mirror',
#  'Right_wing_mirror',
#  'Rearview_mirror',
#  'Centerstack',
#  'Left_wing_mirror',
#  'Centerstack',
#  'Left_wing_mirror',
#  'Forward',
#  'Forward',
#  'Centerstack',
#  'Forward',
#  'Forward',
#  'Centerstack',
#  'Centerstack',
#  'Left_wing_mirror',
#  'Centerstack',
#  'Rearview_mirror',
#  'Centerstack',
#  'Forward',
#  'Right_wing_mirror',
#  'Forward',
#  'Right_wing_mirror',
#  'Forward',
#  'Forward',
#  'Centerstack',
#  'Centerstack',
#  'Left_wing_mirror',
#  'Centerstack',
#  'Forward',
#  'Left_wing_mirror',
#  'Forward',
#  'Right_wing_mirror',
#  'Left_wing_mirror',
#  'Rearview_mirror',
#  'Forward',
#  'Right_wing_mirror',
#  'Centerstack',
#  'Left_wing_mirror',
#  'Forward',
#  'Rearview_mirror',
#  'Left_wing_mirror',
#  'Left_wing_mirror',
#  'Centerstack',
#  'Centerstack',
#  'Rearview_mirror',
#  'Rearview_mirror',
#  'Left_wing_mirror',
#  'Left_wing_mirror',
#  'Centerstack',
#  'Rearview_mirror',
#  'Right_wing_mirror',
#  'Rearview_mirror',
#  'Rearview_mirror',
#  'Centerstack',
#  'Rearview_mirror',
#  'Left_wing_mirror',
#  'Rearview_mirror',
#  'Rearview_mirror',
#  'Rearview_mirror',
#  'Forward',
#  'Left_wing_mirror',
#  'Left_wing_mirror',
#  'Forward',
#  'Forward',
#  'Rearview_mirror',
#  'Rearview_mirror',
#  'Centerstack',
#  'Left_wing_mirror',
#  'Forward',
#  'Forward',
#  'Right_wing_mirror',
#  'Right_wing_mirror',
#  'Left_wing_mirror',
#  'Rearview_mirror',
#  'Forward',
#  'Right_wing_mirror',
#  'Rearview_mirror',
#  'Forward',
#  'Centerstack',
#  'Forward',
#  'Rearview_mirror',
#  'Right_wing_mirror',
#  'Left_wing_mirror',
#  'Rearview_mirror',
#  'Left_wing_mirror',
#  'Rearview_mirror',
#  'Forward',
#  'Rearview_mirror',
#  'Rearview_mirror',
#  'Right_wing_mirror',
#  'Right_wing_mirror',
#  'Left_wing_mirror',
#  'Centerstack',
#  'Rearview_mirror',
#  'Centerstack',
#  'Rearview_mirror',
#  'Rearview_mirror',
#  'Forward',
#  'Right_wing_mirror',
#  'Forward',
#  'Forward',
#  'Left_wing_mirror',
#  'Centerstack',
#  'Forward',
#  'Centerstack',
#  'Left_wing_mirror',
#  'Right_wing_mirror',
#  'Right_wing_mirror',
#  'Centerstack',
#  'Forward',
#  'Rearview_mirror',
#  'Right_wing_mirror',
#  'Left_wing_mirror',
#  'Centerstack',
#  'Rearview_mirror',
#  'Right_wing_mirror',
#  'Centerstack',
#  'Centerstack',
#  'Forward',
#  'Forward',
#  'Centerstack',
#  'Centerstack',
#  'Forward',
#  'Left_wing_mirror',
#  'Left_wing_mirror',
#  'Left_wing_mirror',
#  'Left_wing_mirror',
#  'Centerstack',
#  'Centerstack',
#  'Right_wing_mirror',
#  'Left_wing_mirror',
#  'Right_wing_mirror',
#  'Forward',
#  'Left_wing_mirror',
#  'Centerstack',
#  'Centerstack',
#  'Rearview_mirror',
#  'Centerstack',
#  'Left_wing_mirror',
#  'Left_wing_mirror',
#  'Forward',
#  'Rearview_mirror',
#  'Centerstack',
#  'Forward',
#  'Right_wing_mirror',
#  'Left_wing_mirror',
#  'Left_wing_mirror',
#  'Rearview_mirror',
#  'Right_wing_mirror',
#  'Right_wing_mirror',
#  'Right_wing_mirror',
#  'Rearview_mirror',
#  'Rearview_mirror',
#  'Left_wing_mirror',
#  'Right_wing_mirror',
#  'Right_wing_mirror',
#  'Forward',
#  'Centerstack',
#  'Left_wing_mirror',
#  'Rearview_mirror',
#  'Forward',
#  'Left_wing_mirror',
#  'Right_wing_mirror',
#  'Rearview_mirror',
#  'Left_wing_mirror',
#  'Left_wing_mirror',
#  'Right_wing_mirror',
#  'Left_wing_mirror',
#  'Centerstack',
#  'Rearview_mirror',
#  'Centerstack',
#  'Forward',
#  'Right_wing_mirror',
#  'Rearview_mirror',
#  'Right_wing_mirror',
#  'Centerstack',
#  'Forward',
#  'Forward',
#  'Centerstack',
#  'Forward',
#  'Rearview_mirror',
#  'Centerstack',
#  'Rearview_mirror',
#  'Centerstack',
#  'Forward',
#  'Rearview_mirror',
#  'Rearview_mirror',
#  'Forward',
#  'Left_wing_mirror',
#  'Forward',
#  'Forward',
#  'Centerstack',
#  'Rearview_mirror',
#  'Right_wing_mirror',
#  'Forward',
#  'Right_wing_mirror',
#  'Forward',
#  'Rearview_mirror',
#  'Right_wing_mirror',
#  'Rearview_mirror',
#  'Centerstack',
#  'Right_wing_mirror',
#  'Rearview_mirror',
#  'Rearview_mirror',
#  'Forward',
#  'Forward',
#  'Left_wing_mirror',
#  'Forward',
#  'Centerstack',
#  'Rearview_mirror',
#  'Left_wing_mirror',
#  'Forward',
#  'Forward',
#  'Left_wing_mirror',
#  'Right_wing_mirror',
#  'Forward',
#  'Right_wing_mirror',
#  'Right_wing_mirror',
#  'Rearview_mirror',
#  'Centerstack',
#  'Centerstack',
#  'Rearview_mirror',
#  'Right_wing_mirror',
#  'Centerstack',
#  'Forward',
#  'Centerstack',
#  'Forward',
#  'Right_wing_mirror',
#  'Left_wing_mirror',
#  'Centerstack',
#  'Centerstack',
#  'Right_wing_mirror',
#  'Right_wing_mirror',
#  'Right_wing_mirror',
#  'Rearview_mirror',
#  'Left_wing_mirror',
#  'Forward',
#  'Centerstack',
#  'Rearview_mirror',
#  'Rearview_mirror',
#  'Forward',
#  'Rearview_mirror',
#  'Rearview_mirror',
#  'Centerstack',
#  'Rearview_mirror',
#  'Rearview_mirror',
#  'Rearview_mirror',
#  'Rearview_mirror',
#  'Forward',
#  'Forward',
#  'Right_wing_mirror',
#  'Centerstack',
#  'Right_wing_mirror',
#  'Right_wing_mirror',
#  'Left_wing_mirror',
#  'Forward',
#  'Rearview_mirror',
#  'Centerstack',
#  'Centerstack',
#  'Forward',
#  'Rearview_mirror',
#  'Centerstack',
#  'Forward',
#  'Left_wing_mirror',
#  'Centerstack',
#  'Forward',
#  'Left_wing_mirror',
#  'Centerstack',
#  'Rearview_mirror',
#  'Centerstack',
#  'Rearview_mirror',
#  'Centerstack',
#  'Rearview_mirror',
#  'Right_wing_mirror',
#  'Left_wing_mirror',
#  'Centerstack',
#  'Forward',
#  'Centerstack',
#  'Rearview_mirror',
#  'Right_wing_mirror',
#  'Forward',
#  'Right_wing_mirror',
#  'Rearview_mirror',
#  'Centerstack',
#  'Centerstack',
#  'Rearview_mirror',
#  'Forward',
#  'Forward',
#  'Forward',
#  'Left_wing_mirror',
#  'Left_wing_mirror',
#  'Rearview_mirror',
#  'Forward',
#  'Forward',
#  'Centerstack',
#  'Forward',
#  'Right_wing_mirror',
#  'Rearview_mirror',
#  'Rearview_mirror',
#  'Left_wing_mirror',
#  'Forward',
#  'Right_wing_mirror',
#  'Centerstack',
#  'Left_wing_mirror',
#  'Rearview_mirror',
#  'Right_wing_mirror',
#  'Centerstack',
#  'Right_wing_mirror',
#  'Left_wing_mirror',
#  'Centerstack',
#  'Rearview_mirror',
#  'Forward',
#  'Forward',
#  'Centerstack',
#  'Rearview_mirror',
#  'Centerstack',
#  'Forward',
#  'Forward',
#  'Rearview_mirror',
#  'Right_wing_mirror',
#  'Forward',
#  'Rearview_mirror',
#  'Forward',
#  'Forward',
#  'Rearview_mirror',
#  'Left_wing_mirror',
#  'Centerstack',
#  'Rearview_mirror',
#  'Left_wing_mirror',
#  'Rearview_mirror',
#  'Right_wing_mirror',
#  'Forward',
#  'Right_wing_mirror',
#  'Left_wing_mirror',
#  'Right_wing_mirror',
#  'Centerstack',
#  'Centerstack',
#  'Centerstack',
#  'Centerstack',
#  'Left_wing_mirror',
#  'Centerstack',
#  'Right_wing_mirror',
#  'Right_wing_mirror',
#  'Right_wing_mirror',
#  'Rearview_mirror',
#  'Left_wing_mirror',
#  'Forward',
#  'Rearview_mirror',
#  'Left_wing_mirror',
#  'Rearview_mirror',
#  'Centerstack',
#  'Right_wing_mirror',
#  'Rearview_mirror',
#  'Rearview_mirror',
#  'Left_wing_mirror',
#  'Rearview_mirror',
#  'Left_wing_mirror',
#  'Forward',
#  'Rearview_mirror',
#  'Forward',
#  'Forward',
#  'Right_wing_mirror',
#  'Centerstack',
#  'Rearview_mirror',
#  'Forward',
#  'Right_wing_mirror',
#  'Left_wing_mirror',
#  'Rearview_mirror',
#  'Rearview_mirror',
#  'Centerstack',
#  'Centerstack',
#  'Rearview_mirror',
#  'Right_wing_mirror',
#  'Right_wing_mirror',
#  'Right_wing_mirror',
#  'Right_wing_mirror',
#  'Rearview_mirror',
#  'Left_wing_mirror',
#  'Right_wing_mirror',
#  'Left_wing_mirror',
#  'Rearview_mirror',
#  'Left_wing_mirror',
#  'Left_wing_mirror',
#  'Forward',
#  'Left_wing_mirror',
#  'Rearview_mirror',
#  'Right_wing_mirror',
#  'Rearview_mirror',
#  'Centerstack',
#  'Centerstack',
#  'Right_wing_mirror',
#  'Forward',
#  'Forward',
#  'Rearview_mirror',
#  'Left_wing_mirror',
#  'Centerstack',
#  'Forward',
#  'Centerstack',
#  'Forward',
#  'Left_wing_mirror',
#  'Forward',
#  'Left_wing_mirror',
#  'Centerstack',
#  'Forward',
#  'Left_wing_mirror',
#  'Rearview_mirror',
#  'Centerstack',
#  'Forward',
#  'Left_wing_mirror',
#  'Right_wing_mirror',
#  'Left_wing_mirror',
#  'Centerstack',
#  'Forward',
#  'Rearview_mirror',
#  'Forward',
#  'Centerstack',
#  'Centerstack',
#  'Centerstack',
#  'Right_wing_mirror',
#  'Centerstack',
#  'Forward',
#  'Centerstack',
#  'Left_wing_mirror',
#  'Centerstack',
#  'Rearview_mirror',
#  'Centerstack',
#  'Forward',
#  'Right_wing_mirror',
#  'Forward',
#  'Centerstack',
#  'Left_wing_mirror',
#  'Right_wing_mirror',
#  'Left_wing_mirror',
#  'Rearview_mirror',
#  'Centerstack',
#  'Forward',
#  'Rearview_mirror',
#  'Rearview_mirror',
#  'Forward',
#  'Rearview_mirror',
#  'Forward',
#  'Right_wing_mirror',
#  'Rearview_mirror',
#  'Left_wing_mirror',
#  'Left_wing_mirror',
#  'Rearview_mirror',
#  'Centerstack',
#  'Rearview_mirror',
#  'Forward',
#  'Rearview_mirror',
#  'Forward',
#  'Forward',
#  'Left_wing_mirror',
#  'Rearview_mirror',
#  'Forward',
#  'Forward',
#  'Right_wing_mirror',
#  'Centerstack',
#  'Right_wing_mirror',
#  'Forward',
#  'Centerstack',
#  'Forward',
#  'Rearview_mirror',
#  'Forward',
#  'Rearview_mirror',
#  'Right_wing_mirror',
#  'Forward',
#  'Left_wing_mirror',
#  'Rearview_mirror',
#  'Left_wing_mirror',
#  'Left_wing_mirror',
#  'Left_wing_mirror',
#  'Centerstack',
#  'Left_wing_mirror',
#  'Rearview_mirror',
#  'Left_wing_mirror',
#  'Rearview_mirror',
#  'Rearview_mirror',
#  'Rearview_mirror',
#  'Right_wing_mirror',
#  'Centerstack',
#  'Centerstack',
#  'Centerstack',
#  'Left_wing_mirror',
#  'Left_wing_mirror',
#  'Rearview_mirror',
#  'Forward',
#  'Right_wing_mirror',
#  'Forward',
#  'Forward',
#  'Rearview_mirror',
#  'Left_wing_mirror',
#  'Forward',
#  'Forward',
#  'Forward',
#  'Centerstack',
#  'Right_wing_mirror',
#  'Forward',
#  'Rearview_mirror',
#  'Forward',
#  'Left_wing_mirror']
